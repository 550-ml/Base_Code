# %%
# 基本配置
import logging

# 可以用对应函数输出对应日志
logging.debug("这是 debug 日志")
logging.info("这是 info 日志")
logging.warning("这是 warning 日志")
logging.error("这是 error 日志")
logging.critical("这是 critical 日志")
# 默认日志级别是 WARNING，低于 WARNING 级别的日志不会输出
# Out:
# WARNING:root:这是 warning 日志
# ERROR:root:这是 error 日志
# CRITICAL:root:这是 critical 日志

# %%
# 基本配置
import logging

logging.basicConfig(level=logging.DEBUG)
# 可以用对应函数输出对应日志
logging.debug("这是 debug 日志")
logging.info("这是 info 日志")
logging.warning("这是 warning 日志")
logging.error("这是 error 日志")
logging.critical("这是 critical 日志")
# 默认日志级别是 WARNING，低于 WARNING 级别的日志不会输出
# Out:
# WARNING:root:这是 warning 日志
# ERROR:root:这是 error 日志
# CRITICAL:root:这是 critical 日志

# %%
# for
logging.basicConfig(
    filename="test.log",
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    level=logging.DEBUG,
)
logging.debug("这是 debug 日志")
logging.info("这是 info 日志")
logging.warning("这是 warning 日志")
logging.error("这是 error 日志")
logging.critical("这是 critical 日志")
# Out:
# WARNING:root:这是 warning 日志
# ERROR:root:这是 error 日志
# CRITICAL:root:这是 critical 日志
